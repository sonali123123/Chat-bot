# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# **MAIN**

# %%
signature_boards = [
    {
        "board_name": "Rustic Farmer's Board",
        "price": 48,
        "contents": [
            "Country truffle pâté",
            "Bourbon & Bacon Salami",
            "Aged Gouda",
            "Harbison Spruce Brie",
            "Midnight Moon Cheese"
        ]
    },
    {
        "board_name": "Chef's Board",
        "price": 58,
        "contents": [
            "The Italian Wich",
            "Prosciutto di Parma 24-month aged",
            "Cabot Clothbound Aged Cheddar",
            "Bayley Hazen Blue",
            "Fermín Jamón Serrano"
        ]
    }
]

# %%
charcuterie_and_cheese = {
    "accompaniments": "All boards include warm epi bread, cranberry pecan crisps, and chef’s selection of accoutrements.",
    "charcuterie": [
        {"name": "Sweet Soppressata", "price": 8, "producer": "Salumeria Biellese, New York, NY"},
        {"name": "Chorizo Dry Salame", "price": 9, "producer": "Olli Meats, Oceanside, CA"},
        {"name": "Mortadella with Black Truffle", "price": 7, "producer": "Golfera, Bologna, Italy"},
        {"name": "Hot Capicola", "price": 7, "producer": "Salumeria Biellese, New York, NY"},
        {"name": "Bourbon & Bacon Salami", "price": 7, "producer": "New England Charcuterie, Waltham, MA"},
        {"name": "Prosciutto di Parma 24-month aged", "price": 16, "producer": "Galloni, Langhirano-Parma, Italy"},
        {"name": "Bresaola", "price": 9, "producer": "Tempesta, Chicago, IL"},
        {"name": "Fermín Jamón Serrano", "price": 9, "producer": "Castillo, Spain"}
    ],

      "Cheese_Varieties" : "(R) Raw, (P) Pasteurized, (c) cow, (g) goat, (s) sheep",
    "cheese": [
        {"name": "Bayley Hazen Blue* (c)(R)", "price": 8, "producer": "Jasper Hill Farm, Greensboro, VT"},
        {"name": "Aged Gouda (c)(P)", "price": 7, "producer": "Holland, Netherlands"},
        {"name": "Humboldt Fog Goat (g)(P)", "price": 9, "producer": "Cypress Grove, Arcata, CA"},
        {"name": "Harbison Spruce Brie", "price": 9, "producer": "Jasper Hill Farm, Greensboro, VT"},
        {"name": "Manchego 6-month aged (s)(P)", "price": 8, "producer": "Don Juan, La Mancha, Spain"},
        {"name": "Cabot Clothbound Aged Cheddar (c)(P)", "price": 9, "producer": "Jasper Hill Farm, Greensboro, VT"},
        {"name": "Parmigiano Reggiano Wheel 18-month aged (c)(P)", "price": 11, "producer": "Grassi, Parma, Italy"},
        {"name": "Midnight Moon Cheese (g)(P)", "price": 9, "producer": "Cypress Grove, Arcata, CA"}
    ]
}

# %%
shareables = [
    {"name": "Marinated Olives", "price": 8, "ingredients": "citrus, parsley, chili flake"},
    {"name": "Whipped Feta", "price": 13, "ingredients": "roasted tomato, sumac, dry cured black olives"},
    {"name": "Baked Brie", "price": 24, "ingredients": "shaved apple, fig jam, toasted walnuts, baguette"},
    {"name": "Hummus", "price": 13, "ingredients": "warm naan bread, roasted garlic, local feta, crispy chickpea"},
    {"name": "Traditional Grilled Cheese", "price": 17, "ingredients": "cheddar, muenster, swiss, Dijon mustard"},
    {"name": "Truffle Grilled Cheese", "price": 23, "ingredients": "gruyère, caramelized onions, pecorino tartufo"},
    {"name": "The Italian Wich", "price": 24, "ingredients": "hot capicola, sweet soppressata, mortadella, hot pepper spread, parmesan aioli, pickled onion, tomato, sesame loaf"},
    {"name": "Classic Fondue", "price": 39, "description": "Traditional Alpine style with emmental and gruyère cheese, white wine, garlic, kirsch and nutmeg. Served with apples, baguette, gherkins and potato"}

]

# %%
raw_bar = {
    "category": "RAW BAR",
    "accoutrements": "Traditional accoutrements",
    "items": [
        {
            "name": "Half Dozen Local Oysters",
            "price": 26,
            "description": "Chef's selection of local oysters, spiced cocktail sauce, mignonette"
        },
        {
            "name": "Classic Shrimp Cocktail",
            "price": 29,
            "description": "Jumbo prawns, spiced cocktail sauce, lemon"
        }
    ]
}

# %%
Main_menu = {
    "Signature_Boards" : signature_boards,
    "Charcuterie_and_Cheese" : charcuterie_and_cheese,
    "Shareables" : shareables,
    "Raw_Bar" : raw_bar
}

# %% [markdown]
# **Beverages**

# %%
wine_menu = {
    "BY THE GLASS | BOTTLE": {
        "SPARKLING": [
            {"name": "Perrier-Jouët, Grand Brut, Épernay, France NV", "glass_price": 24, "bottle_price": 94},
            {"name": "Cremant d’Alsace, Pierre Sparr, Brut Rosé, Alsace, France, NV", "glass_price": 16, "bottle_price": 62},
            {"name": "Flor, Prosecco, Veneto, Italy NV", "glass_price": 14, "bottle_price": 54}
        ],
        "WHITES": [
            {"name": "Albariño, Paco & Lola, Rias Baixas, Spain 2022", "glass_price": 15, "bottle_price": 58},
            {"name": "Pinot Grigio, Jermann, Friuli, Italy 2022", "glass_price": 16, "bottle_price": 62},
            {"name": "Sauvignon Blanc, Mulderbosch, South Africa 2021", "glass_price": 16, "bottle_price": 62},
            {"name": "Chardonnay, Stag’s Leap Wine Cellars, Karia, Napa Valley, California 2021", "glass_price": 21, "bottle_price": 82},
            {"name": "Sauvignon Blanc, Cloudy Bay, Marlborough, New Zealand, 2022", "glass_price": 28, "bottle_price": 110},
            {"name": "Friulano, Scarpetta,’Frico’, Friuli, Italy, 2017", "glass_price": 24, "bottle_price": 94},
            {"name": "Riesling, Forge Cellars, Breakneck Creek, Seneca Lake, NY 2020", "glass_price": 20, "bottle_price": 78}
        ],
        "ROSÉ": [
            {"name": "Pinot Noir, Flowers, Sonoma Coast, California 2022", "glass_price": 20, "bottle_price": 78}
        ],
        "REDS": [
            {"name": "Gigondas, Domaine Brusset, Tradition Le Grand Montmirail, Rhône, France 2020", "glass_price": 23, "bottle_price": 90},
            {"name": "Pinot Noir, Holloran ‘Stafford Hill’ Willamette Valley, Oregon 2022", "glass_price": 15, "bottle_price": 58},
            {"name": "Cabernet Sauvignon, Kith & Kin, Napa Valley, California 2021", "glass_price": 23, "bottle_price": 90},
            {"name": "Zinfandel, Ridge, 'Three Valleys', Sonoma County, California 2021", "glass_price": 21, "bottle_price": 82}
        ],
        "SWEET & FORTIFIED": [
            {"name": "Fino Sherry, Valdespino ‘Inocente’ Macharnudo Vineyard, Spain NV", "size": "3 oz.", "price": 13},
            {"name": "Tawny Port, Cockburn’s, 10 Year, Oporto, Portugal", "size": "3 oz.", "price": 13}
        ]
    }
}

# %%
half_bottle_wines = {
    "category": "HALF BOTTLE (375 ML BOTTLE)",
    "wines": {
        "SPARKLING": [
            {"name": "Blanc de Blancs, Delamotte, Le Mesnil sur Oger, France NV", "price": 90},
            {"name": "Brut, Laurent-Perrier 'La Cuvee', France NV", "price": 48}
        ],
        "WHITE WINES": [
            {"name": "Chardonnay, Kosta Browne, 'One Sixteen', Russian River Valley, California 2016", "price": 105}
        ],
        "RED WINES": [
            {"name": "Pinot Noir, Patz & Hall, Sonoma Coast, California 2016", "price": 54},
            {"name": "Super Tuscan, Antinori 'Tignanello', Tuscany, Italy 2019", "price": None}  # Assuming the price is not provided for this item
        ]
    }
}

# %%
reserved_list = {
    "category": "RESERVED LIST",
    "wines": {
        "WHITE WINES": [
            {"name": "Sancerre, Daniel Crochet, Cuvée Prestige, Loire, France 2021", "glass_price": 35, "bottle_price": 138}
        ],
        "RED WINES": [
            {"name": "Tempranillo, Bodegas Muga, Selección Especial, Rioja, Spain 2018", "glass_price": 33, "bottle_price": 130},
            {"name": "Merlot, Duckhorn, Napa Valley, California 2020", "glass_price": 30, "bottle_price": 118},
            {"name": "Red Blend, The Prisoner, Napa, California 2021", "glass_price": 31, "bottle_price": 124},
            {"name": "Bordeaux, Château Bellegrave, Medoc, Bordeaux, France 2017", "glass_price": 42, "bottle_price": 168}
        ]
    }
}

# %%
beer_on_draft = {
    "category": "BEER ON DRAFT",
    "beers": [
        {"name": "Night Shift 'Nite Lite'", "type": "Light Lager", "origin": "Everett, MA", "price": 10},
        {"name": "Maine Beer Co. 'Lunch IPA'", "type": "Freeport, ME", "price": 13},
        {"name": "Ipswich Ale Brewery 'Ipswich Oatmeal Stout'", "type": "Ipswich, MA", "price": 11},
        {"name": "Down East Cider Co. 'Seasonal Offering'", "type": "Boston, MA", "price": 11}
    ]
}

# %%
Beverages_menu = {
    "Wine_menu" : wine_menu,
    "half_bottle_wines" : half_bottle_wines,
    "Reserved_list" : reserved_list,
    "beer_on_draft" : beer_on_draft
}

# %%
Chefs_Board_Menu = {
    "Description" : "During your next visit, try Chef's Board featuring The Italian Wich, prosciutto di Parma 24-month aged, Vault No. 5 Cave Aged Cheddar, Bayley Hazen Blue, Fermin Iberico Lomo. Join Chef Steven Morlino at Cheese Meet Wine for bites, boards, and more. Enjoy charcuterie, cheese from around the world, sandwiches, fondue and perfectly paired wines.",
    "Main" : Main_menu,
    "Beverages" : Beverages_menu
}


Chefs_Board_Menu
# Out:
# {'Description': "During your next visit, try Chef's Board featuring The Italian Wich, prosciutto di Parma 24-month aged, Vault No. 5 Cave Aged Cheddar, Bayley Hazen Blue, Fermin Iberico Lomo. Join Chef Steven Morlino at Cheese Meet Wine for bites, boards, and more. Enjoy charcuterie, cheese from around the world, sandwiches, fondue and perfectly paired wines.",
#  'Main': {'Signature_Boards': [{'board_name': "Rustic Farmer's Board",
#     'price': 48,
#     'contents': ['Country truffle pâté',
#      'Bourbon & Bacon Salami',
#      'Aged Gouda',
#      'Harbison Spruce Brie',
#      'Midnight Moon Cheese']},
#    {'board_name': "Chef's Board",
#     'price': 58,
#     'contents': ['The Italian Wich',
#      'Prosciutto di Parma 24-month aged',
#      'Cabot Clothbound Aged Cheddar',
#      'Bayley Hazen Blue',
#      'Fermín Jamón Serrano']}],
# ...

# %% [markdown]
# **Fratelli Menu**

# %%
Fratelli_dinner_menu = {
    "APPETIZERS": [
        {"name": "Eggplant Parmigiana", "price": 21.95, "description": "Layered eggplant / fior di latte mozzarella / pomodoro / basil"},
        {"name": "Meatballs & Homemade Ricotta", "price": 21.95, "description": "Certified Angus ground beef / fresh imported ricotta / pomodoro / crostini"},
        {"name": "Dry Aged Beef Carpaccio", "price": 25.95, "description": "Arugula, shaved parmigiano, truffle essence"},
        {"name": "Sautéed Mussels & Clams", "price": 23.95, "description": "Clams & mussels / sautéed garlic / parsley / pinot grigio"},
        {"name": "Calamari & Fritto Misto", "price": 25.95, "description": "Calamari / shrimp / scallops / fried onion strings / citrus aioli"},
        {"name": "Caprese con Mozzarella di Bufala", "price": 23.95, "description": "Vine-ripened tomatoes / basil pesto"},
        {"name": "Bruschette", "price": 24.95, "description": "Burrata / broccoli rabe / roasted peppers / eggplant caponata"},
        {"name": "Zucchini Flowers", "price": 23.95, "description": "Seasonal flowers stuffed with goat cheese / lemon zest / tempura zucchini chips"},
        {"name": "Grilled Octopus", "price": 24.95, "description": "Positano style. Creamy burrata / eggplant caponata / cherry tomatoes / basil"},
        {"name": "Shrimp Scampi", "price": 26.95, "description": "Jumbo shrimp / sautéed spinach / garlic / limoncello"},
        {"name": "Charcuterie", "price": 27.95, "description": "Mortadella / sopressata / Parma prosciutto / Italian cheeses"},
        {"name": "Insalata Mista", "price": 16.95, "description": "Passion fruit purée / roasted pears / parmigiano cheese crostini / spicy pecans"},
        {"name": "Caesar", "price": 16.95, "description": "Blue sky bibb lettuce / biscottino di pane / anchovies / homemade dressing"}
    ],
  "PASTAS": [
        {"name": "Positano", "price": 31.95, "description": "Vongole Macchiato manilla clams / cherry tomatoes / parsley / pinot grigio"},
        {"name": "Sorrento", "price": 29.95, "description": "Gnocchi alla Sorrentina homemade potato dumplings / mozzarella / pomodoro / basil"},
        {"name": "Amalfi", "price": "MP", "description": "Lobster Fra’ Diavolo whole maine lobster / lobster fumet / colino cherry tomatoes"},
        {"name": "Ravello", "price": 28.95, "description": "Ravioli Caprese soft pillows / brigante cheese / marjoram / parmigiano / pomodoro / basil"},
        {"name": "Capri", "price": "MP", "description": "Risotto/Paella of the Day arborio italian rice with chefs choice for the day"},
        {"name": "Nerano", "price": 29.95, "description": "Zucchini Pasta zucchini, provolone del monaco / shaved parmigiano"},
        {"name": "Napoli", "price": 28.95, "description": "Broccoli Rabe & Sausage neapolitan (friarielle) rabe / homemade sweet sausage"},
        {"name": "Gragnano", "price": 30.95, "description": "Carbonara smoked pancetta / guanciale / egg yolk / parmigiano / pecorino romano"},
        {"name": "Pompei", "price": 28.95, "description": "Puttanesca gaeta olives / capers / anchovies / cherry tomatoes"},
        {"name": "Ischia", "price": 28.95, "description": "Amatriciana smoked pancetta / guanciale / onion / colino cherry tomatoes"},
        {"name": "Maori", "price": 29.95, "description": "Tagliolini con Meatballs angel hair / pomodoro sauce / mom’s meatballs"},
        {"name": "Vesuvio", "price": 31.95, "description": "Paccheri di Gragnano alla Ragu’ homemade bolognese with lamb / pork / beef"}
    ],
  "SECONDI": [
        {"name": "Chicken Parmigiana", "price": 39.95, "description": "“a north end classic” gragnano penne / pomodoro / basil"},
        {"name": "Alaskan King Salmon", "price": 44.95, "description": "Pan seared / roasted fennel / shallots / white bean purée"},
        {"name": "Veal Ossobuco, Marcho Farms", "price": 49.95, "description": "Arborio saffron risotto / sautéed spinach"},
        {"name": "Braised Beef Short Ribs", "price": 49.95, "description": "Creamy parmigiano polenta / roasted chestnuts / red wine reduction / sweet Italian glaze"},
        {"name": "Chilean Sea Bass in Agrodolce", "price": 52.95, "description": "Baby bok choy / herbed potato gallette / carrot fondue"},
        {"name": "Truffle Crusted Tuna", "price": 49.95, "description": "Seared rare / Japanese eggplant / wilted spinach / sweet baby peppers / olives"},
        {"name": "7-Spice Murray’s Brick Chicken", "price": 49.95, "description": "7-spice marinated half chicken roasted “under the brick” / served with double mashed"},
        {"name": "Veal Chop Milanese", "price": 59.95, "description": "Topped with arugula salad / lemon / shaved parmigiano"},
        {"name": "Mediterranean Branzino", "price": 49.95, "description": "Boneless grilled / roasted potatoes / spinach / carrots / parsley pesto"},

    ],
  "ON THE SIDE": [
        {"name": "Baby Brussels Sprouts", "price": 16.95, "description": "Pancetta, sweet black balsamic"},
        {"name": "Our Hand-Cut Italian Fries", "price": 15.95, "description": None},
        {"name": "Double Mashed Potatoes", "price": 15.95, "description": None},
        {"name": "Roasted Baby Carrots", "price": 16.95, "description": None},
        {"name": "Roasted Wild Mushrooms", "price": 17.95, "description": None},
        {"name": "Spicy Sautéed Broccoli Rabe", "price": 17.95, "description": None},
    ],

  "CERTIFIED PRIME BEEF & CHOPS": {
        "description": "Steaks / chops a la carte & cooked in brick oven",
        "items": [
            {"name": "12 oz. Prime Filet Mignon", "price": 72.95, "description": "21 day aged - gentle & luxurious flavor"},
            {"name": "22 oz. Prime Bone-in NY Sirloin", "price": 84.95, "description": "35 day dry aged - bold / rich / nutty flavor"},
            {"name": "24 oz. Prime Bone-in Cowboy Ribeye", "price": 99.95, "description": "35 day aged - tender bite / rich flavor"},
            {"name": "36oz. Prime Tomahawk Rib Eye (for two)", "price": 169.95, "description": "35 Day Dry Aged - Tender Bite, Rich Flavor"},
            {"name": "Colorado Rack of Lamb", "price": 68.95, "description": "Marcho Farms / pasture raised"},
            {"name": "Veal Chop Valdostana", "price": 69.95, "description": "Fontina / prosciutto stuffed veal chop"}
        ]
    },
    "NOTES": [
        "The chefs are thrilled to use produce from local farms, natural meats, and meticulously selected fish.",
        "A 20% gratuity will be added for parties of 6 or more.",
        "*Consuming raw or undercooked foods may increase the risk of food-borne illness. Before placing your order, please inform y",
    ]
}

# %%
About_Fratelli = {"Description" : "Two friends, turned two brothers through the passion for food and the ultimate in hospitality. They met in Boston’s North End as friends and their Italian roots brought them together as family. Both acclaimed Italian restaurateurs throughout Boston, now coming together to present Fratelli. A world class Italian restaurant and an unparalleled experience in the Encore Boston Harbor.Due to Fratelli’s location on the casino floor, patrons must be 21 years of age or older to dine with us."}

# %%
fratelli_rush_hour_menu = {
    "Fratelli Rush Hour": {
        "description": "Skip the traffic and spend rush hour at Fratelli with a four-course meal from 4–6 p.m. every Monday through Thursday. For $49.95, enjoy any appetizer on the full menu, any pasta as a mid-course and a choice of four classic entrées such as marinated Tuscan sirloin steak tips and 7-spice brick chicken. Save room for dessert, as every meal ends on a sweet note with Chef’s house made tiramisu.",
        "price": 49.95,
        "available_days": ["Monday", "Tuesday", "Wednesday", "Thursday"],
        "available_hours": "4–6 p.m.",
        "courses": [
            {"course_type": "Appetizer", "options": "Any appetizer on the full menu"},
            {"course_type": "Mid-course", "options": "Any pasta"},
            {"course_type": "Entrée", "options": "A choice of four classic entrées such as marinated Tuscan sirloin steak tips and 7-spice brick chicken"},
            {"course_type": "Dessert", "options": "Chef’s house made tiramisu"}
        ]
    },
  "About_Fratelli" : About_Fratelli,
  "Fratelli_dinner_menu" : Fratelli_dinner_menu

}
fratelli_rush_hour_menu
# Out:
# {'Fratelli Rush Hour': {'description': 'Skip the traffic and spend rush hour at Fratelli with a four-course meal from 4–6 p.m. every Monday through Thursday. For $49.95, enjoy any appetizer on the full menu, any pasta as a mid-course and a choice of four classic entrées such as marinated Tuscan sirloin steak tips and 7-spice brick chicken. Save room for dessert, as every meal ends on a sweet note with Chef’s house made tiramisu.',
#   'price': 49.95,
#   'available_days': ['Monday', 'Tuesday', 'Wednesday', 'Thursday'],
#   'available_hours': '4–6 p.m.',
#   'courses': [{'course_type': 'Appetizer',
#     'options': 'Any appetizer on the full menu'},
#    {'course_type': 'Mid-course', 'options': 'Any pasta'},
#    {'course_type': 'Entrée',
#     'options': 'A choice of four classic entrées such as marinated Tuscan sirloin steak tips and 7-spice brick chicken'},
#    {'course_type': 'Dessert', 'options': 'Chef’s house made tiramisu'}]},
# ...

# %%
surf_and_turf_special = {
    "Surf and Turf for Two": {
        "description": "Join us every Sunday for a Surf and Turf special for two. For $250, enjoy a 20 ounce peppercorn crusted dry-aged Prime NY Strip and a broiled 2 ½ pound Maine lobster prepared beurre blanc style to share.",
        "price": 250,
        "available_day": "Sunday",
        "items": [
            {"name": "Peppercorn Crusted Dry-Aged Prime NY Strip", "weight": "20 oz"},
            {"name": "Broiled 2 ½ Pound Maine Lobster", "preparation": "Beurre blanc style"}
        ]
    }
}

# %%
prime_rib_feature = {
    "event_name": "Prime Rib Feature",
    "days": ["Thursdays", "Sundays"],
    "details": {
        "description": "Join us at Rare Steakhouse every Thursday and Sunday for a special prime rib dinner featuring your choice of the full or signature cut served with roasted carrots, horseradish-whipped potatoes and accompanying sauces.",
        "pricing": {
            "full_cut": "$65",
            "signature_cut": "$48"
        },
        "reservations": "Reservations are recommended.",
        "restrictions": [
            "Dine-in only.",
            "Promotion not valid on holidays."
        ]
    }
}

# %%
Football_watch_party_info = {
    "event_name": "Football Watch Parties at Night Shift Brewing Kitchen & Tap",
    "dates": ["January 14", "January 21", "January 28"],
    "start_time": "12 p.m.",
    "details": {
        "features": "Join us for drink features, prize drawings",
        "buffet": {
            "type": "All You Can Eat Buffet",
            "items": ["Wings", "Nachos", "Sliders", "Desserts", "and more"]
        },
        "price": "$49.99 per guest",
        "includes": ["Two glasses of wine", "Two Nite Lite"],
        "experience": "A walk-in experience.",
        "additional_info": [
            "Additional beverages can be purchased at the bar.",
            "Gratuity not included."
        ]
    }
}

# %%
Special_Menu_Events = {
    "Football_watch_party_info" : Football_watch_party_info,
    "prime_rib_feature " : prime_rib_feature ,
    "surf_and_turf_special" : surf_and_turf_special,
    "fratelli_rush_hour_menu" : fratelli_rush_hour_menu,
    "Chefs_Board_Menu" : Chefs_Board_Menu
}

# %%
encore_experiences = {
    "location": "Encore Boston Harbor",
    "description": "There is always something new to experience at Encore Boston Harbor. From our exclusive menus to an exciting master class with one of our Encore chefs or sommeliers, choosing to add a one-of-a-kind experience to your visit will transform moments here into unforgettable memories.",
    "Special_Menu_Events" : Special_Menu_Events
}
encore_experiences
# Out:
# {'location': 'Encore Boston Harbor',
#  'description': 'There is always something new to experience at Encore Boston Harbor. From our exclusive menus to an exciting master class with one of our Encore chefs or sommeliers, choosing to add a one-of-a-kind experience to your visit will transform moments here into unforgettable memories.',
#  'Special_Menu_Events': {'Football_watch_party_info': {'event_name': 'Football Watch Parties at Night Shift Brewing Kitchen & Tap',
#    'dates': ['January 14', 'January 21', 'January 28'],
#    'start_time': '12 p.m.',
#    'details': {'features': 'Join us for drink features, prize drawings',
#     'buffet': {'type': 'All You Can Eat Buffet',
#      'items': ['Wings', 'Nachos', 'Sliders', 'Desserts', 'and more']},
#     'price': '$49.99 per guest',
#     'includes': ['Two glasses of wine', 'Two Nite Lite'],
#     'experience': 'A walk-in experience.',
#     'additional_info': ['Additional beverages can be purchased at the bar.',
# ...
